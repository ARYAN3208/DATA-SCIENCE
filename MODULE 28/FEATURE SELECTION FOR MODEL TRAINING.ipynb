# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_forest_dataset_cleaned_dataset.xls')

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI      Classes  Region
# 0  1.3  3.4  0.5  not fire          0
# 1  1.0  3.9  0.4  not fire          0
# 2  0.3  2.7  0.1  not fire          0
# 3  0.0  1.7  0.0  not fire          0
# 4  1.2  3.9  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
## dropping month,day and year
df.drop(['day', 'month', 'year'],axis=1)
# Out:
#      Unnamed: 0  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             0           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             1           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             2           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             3           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             4           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..          ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238         238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239         239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240         240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241         241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242         242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire          0
# 1     not fire          0
# 2     not fire          0
# 3     not fire          0
# 4     not fire          0
# ..            ...     ...
# 238       fire          1
# 239   not fire          1
# 240   not fire          1
# 241   not fire          1
# 242  not fire           1
#
# [243 rows x 13 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI      Classes  Region
# 0  1.3  3.4  0.5  not fire          0
# 1  1.0  3.9  0.4  not fire          0
# 2  0.3  2.7  0.1  not fire          0
# 3  0.0  1.7  0.0  not fire          0
# 4  1.2  3.9  0.5  not fire          0

# %%
df.tail()
# Out:
#      Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC  \
# 238         238   26      9  2012           30  65  14   0.0  85.4  16.0
# 239         239   27      9  2012           28  87  15   4.4  41.1   6.5
# 240         240   28      9  2012           27  87  29   0.5  45.9   3.5
# 241         241   29      9  2012           24  54  18   0.1  79.7   4.3
# 242         242   30      9  2012           24  64  15   0.2  67.3   3.8
#
#        DC  ISI   BUI  FWI       Classes  Region
# 238  44.5  4.5  16.9  6.5       fire          1
# 239   8.0  0.1   6.2  0.0   not fire          1
# 240   7.9  0.4   3.4  0.2   not fire          1
# 241  15.2  1.7   5.1  0.7   not fire          1
# 242  16.5  1.2   4.8  0.5  not fire           1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %% [markdown]
# ### ENCODING THE CODE

# %%
### encoding 
df['Classes'] = np.where(df['Classes'].str.contains("not fire"), 0, 1)

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI  Classes  Region
# 0  1.3  3.4  0.5        0       0
# 1  1.0  3.9  0.4        0       0
# 2  0.3  2.7  0.1        0       0
# 3  0.0  1.7  0.0        0       0
# 4  1.2  3.9  0.5        0       0

# %%
df.tail()
# Out:
#      Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC  \
# 238         238   26      9  2012           30  65  14   0.0  85.4  16.0
# 239         239   27      9  2012           28  87  15   4.4  41.1   6.5
# 240         240   28      9  2012           27  87  29   0.5  45.9   3.5
# 241         241   29      9  2012           24  54  18   0.1  79.7   4.3
# 242         242   30      9  2012           24  64  15   0.2  67.3   3.8
#
#        DC  ISI   BUI  FWI  Classes  Region
# 238  44.5  4.5  16.9  6.5        1       1
# 239   8.0  0.1   6.2  0.0        0       1
# 240   7.9  0.4   3.4  0.2        0       1
# 241  15.2  1.7   5.1  0.7        0       1
# 242  16.5  1.2   4.8  0.5        0       1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
### independent and dependent features
x=df.drop('FWI',axis=1)
y=df['FWI']

# %%
x.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  Classes  Region
# 0  1.3  3.4        0       0
# 1  1.0  3.9        0       0
# 2  0.3  2.7        0       0
# 3  0.0  1.7        0       0
# 4  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
### train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    x, y, test_size=0.25, random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 15), (61, 15))

# %%
###feautre selection based correlation
X_train.corr()
# Out:
#              Unnamed: 0       day     month  year  Temperature        RH  \
# Unnamed: 0     1.000000  0.128858  0.468895   NaN     0.222788 -0.367511
# day            0.128858  1.000000 -0.030327   NaN     0.082147 -0.072161
# month          0.468895 -0.030327  1.000000   NaN    -0.015272 -0.031036
# year                NaN       NaN       NaN   NaN          NaN       NaN
# Temperature    0.222788  0.082147 -0.015272   NaN     1.000000 -0.656095
# RH            -0.367511 -0.072161 -0.031036   NaN    -0.656095  1.000000
# Ws            -0.187296  0.043611 -0.037508   NaN    -0.305977  0.225736
# Rain          -0.055222 -0.073855  0.008632   NaN    -0.317512  0.241656
# FFMC           0.244364  0.253695 -0.006620   NaN     0.694768 -0.653023
# DMC            0.271848  0.496505  0.053308   NaN     0.498173 -0.414601
# DC             0.072597  0.540581  0.121493   NaN     0.390684 -0.236078
# ISI            0.317535  0.190732  0.076010   NaN     0.629848 -0.717804
# BUI            0.201261  0.529327  0.074529   NaN     0.473609 -0.362317
# Classes        0.196463  0.244289  0.005476   NaN     0.542141 -0.456876
# Region         0.867030  0.019528 -0.014930   NaN     0.254549 -0.394665
#
#                    Ws      Rain      FFMC       DMC        DC       ISI  \
# Unnamed: 0  -0.187296 -0.055222  0.244364  0.271848  0.072597  0.317535
# day          0.043611 -0.073855  0.253695  0.496505  0.540581  0.190732
# month       -0.037508  0.008632 -0.006620  0.053308  0.121493  0.076010
# year              NaN       NaN       NaN       NaN       NaN       NaN
# Temperature -0.305977 -0.317512  0.694768  0.498173  0.390684  0.629848
# RH           0.225736  0.241656 -0.653023 -0.414601 -0.236078 -0.717804
# Ws           1.000000  0.251932 -0.190076  0.000379  0.096576 -0.023558
# Rain         0.251932  1.000000 -0.545491 -0.289754 -0.302341 -0.345707
# FFMC        -0.190076 -0.545491  1.000000  0.620807  0.524101  0.750799
# DMC          0.000379 -0.289754  0.620807  1.000000  0.868647  0.685656
# DC           0.096576 -0.302341  0.524101  0.868647  1.000000  0.513701
# ISI         -0.023558 -0.345707  0.750799  0.685656  0.513701  1.000000
# BUI          0.035633 -0.300964  0.607210  0.983175  0.942414  0.643818
# Classes     -0.082570 -0.369357  0.781259  0.617273  0.543581  0.742977
# Region      -0.199969 -0.059022  0.249514  0.212582 -0.060838  0.296441
#
#                   BUI   Classes    Region
# Unnamed: 0   0.201261  0.196463  0.867030
# day          0.529327  0.244289  0.019528
# month        0.074529  0.005476 -0.014930
# year              NaN       NaN       NaN
# Temperature  0.473609  0.542141  0.254549
# RH          -0.362317 -0.456876 -0.394665
# Ws           0.035633 -0.082570 -0.199969
# Rain        -0.300964 -0.369357 -0.059022
# FFMC         0.607210  0.781259  0.249514
# DMC          0.983175  0.617273  0.212582
# DC           0.942414  0.543581 -0.060838
# ISI          0.643818  0.742977  0.296441
# BUI          1.000000  0.612239  0.114897
# Classes      0.612239  1.000000  0.188837
# Region       0.114897  0.188837  1.000000

# %%
### check for  multicolinearity
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ##  checking the correlation between dataset and threshold

# %% [markdown]
# ## threshold is a number (between 0 and 1) that decides how strong a correlation must be before we consider it "too high".

# %%
def correlation(dataset, threshold): ###
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
correlation(X_train,0.90)
# Out:
# {'BUI'}

# %%
## setting threshold
corr_features=correlation(X_train,0.85)

# %%
## drop these feaatures when correlation more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 12), (61, 12))

# %% [markdown]
# ## feature scaling or standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.3353872 , -1.10036414,  1.3585682 , ..., -0.88272888,
#         -0.62963326, -1.10431526],
#        [ 0.29670993,  0.47831144, -1.34865164, ..., -0.86687565,
#         -0.93058524, -1.10431526],
#        [ 1.02936798, -0.53655144,  0.45616158, ...,  0.61540157,
#          2.7271388 ,  0.90553851],
#        ...,
#        [-0.40721642, -1.66417685,  1.3585682 , ..., -1.06504105,
#         -1.06948615, -1.10431526],
#        [ 0.842612  ,  1.49317432, -0.44624503, ...,  0.37760309,
#          0.5973248 ,  0.90553851],
#        [-0.26355798, -0.53655144,  1.3585682 , ..., -1.01748135,
#         -0.86113478, -1.10431526]])

# %% [markdown]
# ### box plots to understand the effects of standard scaler

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train after scaling')
plt.show()

# %% [markdown]
# ### MODEL TRAINNG

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,Y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 0.5794852259712949
# 0.9837833371264647

# %% [markdown]
# ## LASSO REGRESSION

# %%
### lasso regression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,Y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 1.133179772389443
# 0.9492008830014923

# %% [markdown]
# ### RIDGE REGRESSION

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,Y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 0.5985026472551219
# 0.9831633646628333

# %% [markdown]
# ### ELASTIC NET

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score
elastic_net=ElasticNet()
elastic_net.fit(X_train_scaled,Y_train)
y_pred=elastic_net.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 1.8558774509269278
# 0.876030958984173

# %% [markdown]
# ### LASSO CV

# %%
from sklearn.linear_model import LassoCV

lasso = LassoCV(cv=5)
lasso.fit(X_train_scaled, Y_train)

lasso.alpha_
# Out:
# 0.0433104856814398

# %%
lasso.alphas_
# Out:
# array([7.05853002, 6.58280872, 6.13914944, 5.72539132, 5.33951911,
#        4.97965339, 4.64404142, 4.33104857, 4.03915039, 3.76692517,
#        3.51304702, 3.27627941, 3.05546914, 2.84954075, 2.65749124,
#        2.47838523, 2.31135036, 2.15557308, 2.01029467, 1.87480753,
#        1.74845178, 1.63061198, 1.52071419, 1.41822315, 1.32263965,
#        1.23349817, 1.15036452, 1.0728338 , 1.00052839, 0.93309613,
#        0.87020857, 0.81155943, 0.75686304, 0.705853  , 0.65828087,
#        0.61391494, 0.57253913, 0.53395191, 0.49796534, 0.46440414,
#        0.43310486, 0.40391504, 0.37669252, 0.3513047 , 0.32762794,
#        0.30554691, 0.28495408, 0.26574912, 0.24783852, 0.23113504,
#        0.21555731, 0.20102947, 0.18748075, 0.17484518, 0.1630612 ,
#        0.15207142, 0.14182231, 0.13226397, 0.12334982, 0.11503645,
#        0.10728338, 0.10005284, 0.09330961, 0.08702086, 0.08115594,
#        0.0756863 , 0.0705853 , 0.06582809, 0.06139149, 0.05725391,
#        0.05339519, 0.04979653, 0.04644041, 0.04331049, 0.0403915 ,
#        0.03766925, 0.03513047, 0.03276279, 0.03055469, 0.02849541,
#        0.02657491, 0.02478385, 0.0231135 , 0.02155573, 0.02010295,
#        0.01874808, 0.01748452, 0.01630612, 0.01520714, 0.01418223,
#        0.0132264 , 0.01233498, 0.01150365, 0.01072834, 0.01000528,
#        0.00933096, 0.00870209, 0.00811559, 0.00756863, 0.00705853])

# %%
lasso.mse_path_
# Out:
# array([[53.64536329, 65.39074075, 54.89628985, 77.90299066, 39.38236846],
#        [46.99139716, 59.81506814, 49.29840831, 75.6645852 , 35.31758355],
#        [41.14908917, 53.9178721 , 42.49594889, 68.35708298, 31.76996123],
#        [36.05788169, 48.41773965, 36.66879347, 61.92819453, 28.67296816],
#        [31.62067285, 42.76466229, 31.68391904, 56.26841266, 24.93183295],
#        [27.75285367, 37.81922812, 27.42599138, 51.28216115, 21.56888645],
#        [24.3807738 , 33.49107651, 23.7950306 , 45.25481907, 18.66094162],
#        [21.44052804, 29.70161639, 20.70460191, 39.90418045, 16.14837778],
#        [18.876308  , 26.38208059, 18.07969934, 35.23429953, 13.97821475],
#        [16.63960395, 23.47341883, 15.85530749, 31.15712074, 12.10483403],
#        [14.68819307, 20.92329068, 13.97555108, 27.59649208, 10.48862803],
#        [12.98525144, 18.68636627, 12.39173305, 24.48611006,  9.09521221],
#        [11.49893734, 16.72312788, 11.06186319, 21.7677198 ,  7.89445038],
#        [10.2013182 , 14.9991189 ,  9.94965275, 19.39216316,  6.86106557],
#        [ 9.06814642, 13.48429046,  9.02375611, 17.31505177,  5.9722389 ],
#        [ 8.0783105 , 12.15220147,  8.25686268, 15.49825178,  5.20846991],
#        [ 7.21342796, 10.98048099,  7.62613185, 13.90854714,  4.5528438 ],
#        [ 6.45749132,  9.94890861,  7.11117548, 12.51700172,  3.99069111],
#        [ 5.79649781,  9.04007002,  6.69464754, 11.29840502,  3.50929245],
#        [ 5.21843764,  8.23876281,  6.36161441, 10.23043133,  3.09746419],
#        [ 4.71266457,  7.53171188,  6.09923004,  9.29470762,  2.74599653],
#        [ 4.2699656 ,  6.90732196,  5.89645437,  8.47412971,  2.44641798],
#        [ 3.88231419,  6.35546212,  5.74343167,  7.75415263,  2.19155766],
#        [ 3.54271656,  5.86727817,  5.63280675,  7.1220963 ,  1.97520698],
#        [ 3.24507798,  5.43490383,  5.55722342,  6.56690368,  1.79199187],
#        [ 2.98408648,  5.05183908,  5.51072584,  6.07893135,  1.6372624 ],
#        [ 2.75511169,  4.71201421,  5.48822878,  5.64976711,  1.50699679],
#        [ 2.55407274,  4.41024533,  5.48539678,  5.27207134,  1.39771812],
#        [ 2.37754224,  4.14199391,  5.49854058,  4.93929274,  1.30641528],
#        [ 2.22240106,  3.90328437,  5.52452745,  4.64615961,  1.23051895],
#        [ 2.08597116,  3.69063268,  5.56020979,  4.38761378,  1.16776797],
#        [ 1.9659162 ,  3.50098406,  5.6043589 ,  4.15939166,  1.11623041],
#        [ 1.86019735,  3.33165877,  5.65456906,  3.95776947,  1.07424081],
#        [ 1.76703503,  3.18030479,  5.70925192,  3.77949324,  1.04036447],
#        [ 1.6848755 ,  3.04481488,  5.76708269,  3.62171864,  1.01336643],
#        [ 1.61236193,  2.92346604,  5.82695915,  3.48195856,  0.99218458],
#        [ 1.54827557,  2.81461081,  5.88796931,  3.3580375 ,  0.97590638],
#        [ 1.49165092,  2.71684484,  5.94936347,  3.24805179,  0.96383716],
#        [ 1.44154595,  2.62893196,  6.01053016,  3.1503334 ,  0.95513053],
#        [ 1.39716889,  2.54978296,  6.07039933,  3.07232371,  0.94929556],
#        [ 1.35782745,  2.47843742,  6.12975718,  3.0041222 ,  0.94584218],
#        [ 1.32291594,  2.41404782,  6.18769529,  2.94364011,  0.94435089],
#        [ 1.29190414,  2.35586563,  6.24396657,  2.88962691,  0.94446421],
#        [ 1.26432775,  2.30322922,  6.29839177,  2.84193587,  0.94587808],
#        [ 1.23978001,  2.25555322,  6.35084178,  2.79951289,  0.94833447],
#        [ 1.21790628,  2.21233117,  6.40122922,  2.76173546,  0.9516149 ],
#        [ 1.20050936,  2.17308236,  6.44950133,  2.72805794,  0.95553494],
#        [ 1.18699229,  2.1374078 ,  6.49563387,  2.69761451,  0.96008592],
#        [ 1.17530715,  2.10494573,  6.53962597,  2.67077799,  0.96484255],
#        [ 1.16519668,  2.0753744 ,  6.58088402,  2.6467804 ,  0.97382405],
#        [ 1.15638213,  2.04840743,  6.62902142,  2.62528895,  0.98461812],
#        [ 1.14882212,  2.02378482,  6.67747098,  2.60556754,  0.99530039],
#        [ 1.14022549,  1.99462108,  6.72503577,  2.58983628,  1.00579379],
#        [ 1.12948113,  1.96612684,  6.78093863,  2.57642837,  1.01604174],
#        [ 1.11262203,  1.93933008,  6.83470064,  2.56194236,  1.02046694],
#        [ 1.0958183 ,  1.90526693,  6.88925079,  2.54790378,  1.01977494],
#        [ 1.08204069,  1.87525439,  6.94388634,  2.53530727,  1.02007235],
#        [ 1.07082493,  1.84883067,  6.99811191,  2.52460781,  1.01943597],
#        [ 1.06178536,  1.81017348,  7.05152892,  2.51103077,  1.00550177],
#        [ 1.05284721,  1.77006762,  7.10382115,  2.47571909,  0.98174779],
#        [ 1.02416485,  1.73484341,  7.16292526,  2.44482157,  0.9397208 ],
#        [ 0.99910909,  1.70351225,  7.22321392,  2.39306348,  0.90416673],
#        [ 0.97708905,  1.67562248,  7.27348008,  2.34682758,  0.87369645],
#        [ 0.95442695,  1.65076875,  7.32060436,  2.3056167 ,  0.84762125],
#        [ 0.9283557 ,  1.62859583,  7.36559349,  2.26844462,  0.82533995],
#        [ 0.90547575,  1.60856308,  7.40846322,  2.23563266,  0.8063316 ],
#        [ 0.885188  ,  1.59087548,  7.44871272,  2.20628603,  0.79024736],
#        [ 0.86719083,  1.57503781,  7.48767228,  2.18000868,  0.77646968],
#        [ 0.85120934,  1.56084287,  7.52638789,  2.15645172,  0.76479767],
#        [ 0.83700313,  1.54810504,  7.56284344,  2.13504735,  0.75492601],
#        [ 0.82752671,  1.53666093,  7.59750651,  2.1160633 ,  0.74660163],
#        [ 0.8204524 ,  1.52620382,  7.62984888,  2.09899052,  0.74101596],
#        [ 0.81440095,  1.51694313,  7.66087904,  2.08361036,  0.73784263],
#        [ 0.80954175,  1.508594  ,  7.69063375,  2.06935423,  0.7355082 ],
#        [ 0.80537064,  1.50108762,  7.71818336,  2.05575384,  0.73382342],
#        [ 0.80213501,  1.49458856,  7.74486759,  2.04334598,  0.73248902],
#        [ 0.7995228 ,  1.48856315,  7.76374438,  2.03197076,  0.73180343],
#        [ 0.79726076,  1.48333855,  7.78059464,  2.02167019,  0.73243437],
#        [ 0.7956489 ,  1.47854122,  7.79601412,  2.01247727,  0.73476303],
#        [ 0.79424581,  1.47440668,  7.81037129,  2.00402028,  0.73729388],
#        [ 0.79436687,  1.47056839,  7.82392139,  1.9964458 ,  0.73972387],
#        [ 0.79476312,  1.46759918,  7.83644803,  1.98957838,  0.74220264],
#        [ 0.79515659,  1.46527635,  7.84820525,  1.98332757,  0.74600463],
#        [ 0.79593826,  1.46330887,  7.85989013,  1.97763203,  0.74915413],
#        [ 0.79685214,  1.46144733,  7.87042969,  1.97235787,  0.75263274],
#        [ 0.79765042,  1.45997307,  7.88017353,  1.96759352,  0.75585923],
#        [ 0.79872519,  1.4587202 ,  7.88933765,  1.96326434,  0.75897878],
#        [ 0.79986146,  1.45764145,  7.89835021,  1.95930385,  0.76220818],
#        [ 0.80102289,  1.45656798,  7.90662848,  1.95567691,  0.76536482],
#        [ 0.80219607,  1.45575099,  7.91417745,  1.95231327,  0.7684016 ],
#        [ 0.80303546,  1.45507658,  7.92125325,  1.94923375,  0.77113345],
#        [ 0.80406062,  1.45450035,  7.92810251,  1.94643612,  0.77388571],
#        [ 0.80511326,  1.45394714,  7.93458206,  1.94386701,  0.77656093],
#        [ 0.80615298,  1.45350551,  7.94040586,  1.94149608,  0.77911105],
#        [ 0.80702404,  1.45325239,  7.94587796,  1.93978405,  0.78138128],
#        [ 0.80799002,  1.45295063,  7.95128345,  1.9382531 ,  0.78363523],
#        [ 0.80897175,  1.45276362,  7.95609328,  1.93684532,  0.7858259 ],
#        [ 0.80992316,  1.45264458,  7.96051831,  1.93555829,  0.7879052 ],
#        [ 0.81083984,  1.45245646,  7.96454438,  1.93444007,  0.78987055],
#        [ 0.81159833,  1.45247375,  7.96875124,  1.9333224 ,  0.79160469]])

# %%
y_pred=lasso.predict(X_test_scaled)
plt.scatter(Y_test,y_pred)
plt.show()
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 0.6088052588751619
# 0.9822778408356189

# %% [markdown]
# ## RIDGE CV

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,Y_train)
y_pred=ridgecv.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 0.5985026472551219
# 0.9831633646628333

# %%
ridgecv.alphas
# Out:
# (0.1, 1.0, 10.0)

# %% [markdown]
# ### ELASTIC NET CV

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import mean_absolute_error, r2_score
elastic_net=ElasticNetCV(cv=5)
elastic_net.fit(X_train_scaled,Y_train)
y_pred=elastic_net.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,y_pred)
score=r2_score(Y_test,y_pred)
print(mae)
print(score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# 0.6634277046449781
# 0.9806800820926649

# %%
elastic_net.alpha_
# Out:
# 0.037496150696543794

# %% [markdown]
# ## PICKLE THE LEARNING MODEL

# %%
scaler
# Out:
# StandardScaler()

# %%
ridge
# Out:
# Ridge()

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
