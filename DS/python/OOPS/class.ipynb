# %%
## Object-oriented programming is a paradigm that uses objects to design applications and computer programs. OOP allows us to model real-world scenarios using classes and objects. For any end-to-end project, it is essential to use classes and objects to increase code reusability and efficiency.

# %%
### class is a blueprint for creating objects. 
class car:
    pass 
audi = car()
bmw  = car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.car object at 0x0000018737A202F0>
# <__main__.car object at 0x000001873783E710>

# %%
audi.windows = 4
print(audi.windows) ## windows ia a typeof attribute that is present class car
# Out:
# 4

# %%
tata = car()
tata.doors = 4
print(tata.doors)
# Out:
# 4

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## instances and variable
class Dog:
    ## constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age

## create an object
Dog1 = Dog("buddy", 3)
print(Dog1)
print(Dog1.name)
print(Dog1.age)
# Out:
# <__main__.Dog object at 0x0000018737B7DA90>
# buddy
# 3

# %%
## define instance with method.
class dog:
  def __init__(self,name,age):
    self.name = name
    self.age = age

    def bark(self):
        print(f"{self.name} says woof")

    dog1 = ("buddy",3)
    dog1.bark()

# %%
## modelling a bank account
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited, new balance is {self.balance}")
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn, new balance is {self.balance}")
    def get_balance(self):
        return self.balance
