# %%
import logging
## creating logger for module1
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

## create a logger for module 2
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

## basic config settings
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', datefmt='%Y-%m-%d %H:%M:%S')

# %%
## log messages for different messages
logger1.debug('This is a debug message for logger one')
logger2.warning('This is a warning message for module two')
logger2.error('This is an error message')
# Out:
# 2025-11-16 10:58:01 - module1 - DEBUG - This is a debug message for logger one
# 2025-11-16 10:58:01 - module2 - WARNING - This is a warning message for module two
# 2025-11-16 10:58:01 - module2 - ERROR - This is an error message
