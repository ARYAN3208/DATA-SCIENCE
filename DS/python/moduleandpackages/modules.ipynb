# %%
# modules and packages help organize the reuse the code.
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np # np is allias
np.array([1,2,3,4,])
# Out:
# array([1, 2, 3, 4])

# %%
from math import * # * matlab sabkuch import ho gaya jo math package mein hain
sqrt (25)
# Out:
# 5.0
