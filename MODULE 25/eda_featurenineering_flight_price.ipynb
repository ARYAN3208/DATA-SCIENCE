# %% [markdown]
# Dataset Overview
# The dataset contains various features related to flights, with the target variable being the price. The features include:
#
# Airline,
# Date of Journey,
# Source,
# Destination,
# Route,
# Departure Time,
# Arrival Time,
# Duration,
# Total Stops,
# Additional Info,
# The dataset consists of 11 columns and 10,683 entries. All features except the target price are of object type, indicating they are stored as strings and require conversion.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
d
