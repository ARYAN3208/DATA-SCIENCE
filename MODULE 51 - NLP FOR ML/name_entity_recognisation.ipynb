# %%
sentences="Ratan Tata visited Chennai on Monday to inaugurate the new TCS research center with Sundar Pichai and Nandan Nilekani."

# %%
import nltk
words=nltk.word_tokenize(sentences)

# %%
tag=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\lande\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\lande\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger_eng')


sentence = "Ratan Tata visited Chennai on Monday to inaugurate the new TCS research center."

# Tokenize
words = word_tokenize(sentence)

# POS tagging
pos_tags = nltk.pos_tag(words)

# Named Entity Recognition
ner = nltk.ne_chunk(pos_tags)

print(ner)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\lande\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[5], line 15
#      12 pos_tags = nltk.pos_tag(words)
#      14 # Named Entity Recognition
# ---> 15 ner = nltk.ne_chunk(pos_tags)
#      17 print(ner)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\nltk\chunk\__init__.py:192, in ne_chunk(tagged_tokens, binary)
#     190     chunker = ne_chunker(fmt="binary")
#     191 else:
# --> 192     chunker = ne_chunker()
#     193 return chunker.parse(tagged_tokens)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\nltk\chunk\__init__.py:174, in ne_chunker(fmt)
#     170 def ne_chunker(fmt="multiclass"):
#     171     """
# ...
