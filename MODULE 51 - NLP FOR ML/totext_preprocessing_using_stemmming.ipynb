# %%
words=['eating','eaten','eats','going','gone','goes']

# %% [markdown]
# Porter Stemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word+"----->"+stemming.stem(word))
# Out:
# eating----->eat
# eaten----->eaten
# eats----->eat
# going----->go
# gone----->gone
# goes----->goe

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %% [markdown]
# RegexpStemmer

# %%
from nltk.stem import RegexpStemmer

# %%
reg=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg.stem('eating')
# Out:
# 'eat'

# %%
reg.stem("ingeating")
# Out:
# 'ingeat'

# %% [markdown]
# Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snow=SnowballStemmer('english')

# %%
for word in words:
    print(word+"------>"+snow.stem(word))
# Out:
# eating------>eat
# eaten------>eaten
# eats------>eat
# going------>go
# gone------>gone
# goes------>goe

# %%
stemming.stem('fairly'),stemming.stem('sportingly')
# Out:
# ('fairli', 'sportingli')

# %%
snow.stem('fairly'),snow.stem('sportingly')
# Out:
# ('fair', 'sport')

# %% [markdown]
# Here compared to other stemming method the snoball stemmer gives proper stem word for the words
